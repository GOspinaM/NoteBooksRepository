# %% [markdown]
# #Data Cleaning of a Dataset

# %% [markdown]
# This notebook puts into practice the cleaning of data from a Kaggle dataset.

# %% [markdown]
# **Objectives:**
#
# *   Replace null values
# * Analyze for duplicate rows
# * Transform elements
# * Transform data types
# * Create columns
# * Delete columns
# * Results
# * Author

# %% [markdown]
# libraries used

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# CSV reading

# %%
df = pd.read_csv('my_file (1).csv')
df.head(5)
# Out:
#    Rank  Peak All Time Peak  Actual gross Actual gross(in 2022 dollars)  \
# 0     1     1             2  $780,000,000                  $780,000,000
# 1     2     1          7[2]  $579,800,000                  $579,800,000
# 2     3  1[4]          2[5]  $411,000,000                  $560,622,615
# 3     4  2[7]         10[7]  $397,300,000                  $454,751,555
# 4     5  2[4]           NaN  $345,675,146                  $402,844,849
#
#          Artist                   Tour title    Year(s)  Shows Average gross  \
# 0  Taylor Swift              The Eras Tour †  2023–2024     56   $13,928,571
# 1       Beyoncé       Renaissance World Tour       2023     56   $10,353,571
# 2       Madonna  Sticky & Sweet Tour ‡[4][a]  2008–2009     85    $4,835,294
# 3          Pink  Beautiful Trauma World Tour  2018–2019    156    $2,546,795
# 4  Taylor Swift      Reputation Stadium Tour       2018     53    $6,522,173
#
#   Ref.
# 0  [1]
# 1  [3]
# 2  [6]
# 3  [7]
# 4  [8]

# %% [markdown]
# ###info about DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Rank                           20 non-null     int64
#  1   Peak                           9 non-null      object
#  2   All Time Peak                  6 non-null      object
#  3   Actual gross                   20 non-null     object
#  4   Actual gross(in 2022 dollars)  20 non-null     object
#  5   Artist                         20 non-null     object
#  6   Tour title                     20 non-null     object
#  7   Year(s)                        20 non-null     object
#  8   Shows                          20 non-null     int64
#  9   Average gross                  20 non-null     object
#  10  Ref.                           20 non-null     object
# dtypes: int64(2), object(9)
# memory usage: 1.8+ KB

# %% [markdown]
# Amount of null data in the df

# %%
df.isnull().sum()
# Out:
# Rank                              0
# Peak                             11
# All Time Peak                    14
# Actual gross                      0
# Actual gross(in 2022 dollars)     0
# Artist                            0
# Tour title                        0
# Year(s)                           0
# Shows                             0
# Average gross                     0
# Ref.                              0
# dtype: int64

# %% [markdown]
# replace null data with 0

# %%
df.fillna(0, inplace=True)

# %%
df.head(6)
# Out:
#    Rank  Peak All Time Peak  Actual gross Actual gross(in 2022 dollars)  \
# 0     1     1             2  $780,000,000                  $780,000,000
# 1     2     1          7[2]  $579,800,000                  $579,800,000
# 2     3  1[4]          2[5]  $411,000,000                  $560,622,615
# 3     4  2[7]         10[7]  $397,300,000                  $454,751,555
# 4     5  2[4]             0  $345,675,146                  $402,844,849
# 5     6  2[4]         10[9]  $305,158,363                  $388,978,496
#
#          Artist                   Tour title    Year(s)  Shows Average gross  \
# 0  Taylor Swift              The Eras Tour †  2023–2024     56   $13,928,571
# 1       Beyoncé       Renaissance World Tour       2023     56   $10,353,571
# 2       Madonna  Sticky & Sweet Tour ‡[4][a]  2008–2009     85    $4,835,294
# 3          Pink  Beautiful Trauma World Tour  2018–2019    156    $2,546,795
# 4  Taylor Swift      Reputation Stadium Tour       2018     53    $6,522,173
# 5       Madonna                The MDNA Tour       2012     88    $3,467,709
#
#   Ref.
# 0  [1]
# 1  [3]
# 2  [6]
# 3  [7]
# 4  [8]
# 5  [9]

# %% [markdown]
# check for changes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Rank                           20 non-null     int64
#  1   Peak                           20 non-null     object
#  2   All Time Peak                  20 non-null     object
#  3   Actual gross                   20 non-null     object
#  4   Actual gross(in 2022 dollars)  20 non-null     object
#  5   Artist                         20 non-null     object
#  6   Tour title                     20 non-null     object
#  7   Year(s)                        20 non-null     object
#  8   Shows                          20 non-null     int64
#  9   Average gross                  20 non-null     object
#  10  Ref.                           20 non-null     object
# dtypes: int64(2), object(9)
# memory usage: 1.8+ KB

# %% [markdown]
# check for duplicate rows

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# dtype: bool

# %% [markdown]
# ###transform objects and remove unnecessary signs

# %%
df['Actual gross'] = df['Actual gross'].str.replace(r'[$,]', '', regex=True).str.strip()
df['Actual gross'] = df['Actual gross'].str.replace(r'\[.*?\]', '', regex=True).str.strip()

df["Actual gross(in 2022 dollars)"] = df["Actual gross(in 2022 dollars)"].str.replace(r'[$,]', '', regex=True).str.strip()
df["Actual gross(in 2022 dollars)"] = df["Actual gross(in 2022 dollars)"].str.replace(r'\[.*?\]', '', regex=True).str.strip()

df['Average gross'] = df['Average gross'].str.replace(r'[$,]', '', regex=True).str.strip()
df['Average gross'] = df['Average gross'].str.replace(r'\[.*?\]', '', regex=True).str.strip()

# %%
df.head(5)
# Out:
#    Rank  Peak All Time Peak Actual gross Actual gross(in 2022 dollars)  \
# 0     1     1             2    780000000                     780000000
# 1     2     1          7[2]    579800000                     579800000
# 2     3  1[4]          2[5]    411000000                     560622615
# 3     4  2[7]         10[7]    397300000                     454751555
# 4     5  2[4]             0    345675146                     402844849
#
#          Artist                   Tour title    Year(s)  Shows Average gross  \
# 0  Taylor Swift              The Eras Tour †  2023–2024     56      13928571
# 1       Beyoncé       Renaissance World Tour       2023     56      10353571
# 2       Madonna  Sticky & Sweet Tour ‡[4][a]  2008–2009     85       4835294
# 3          Pink  Beautiful Trauma World Tour  2018–2019    156       2546795
# 4  Taylor Swift      Reputation Stadium Tour       2018     53       6522173
#
#   Ref.
# 0  [1]
# 1  [3]
# 2  [6]
# 3  [7]
# 4  [8]

# %% [markdown]
# transform objects to integers (int64)

# %%
df["Actual gross"] = df["Actual gross"].astype(int)
df["Actual gross(in 2022 dollars)"] = df["Actual gross(in 2022 dollars)"].astype(int)
df ['Average gross'] = df['Average gross'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Rank                           20 non-null     int64
#  1   Peak                           20 non-null     object
#  2   All Time Peak                  20 non-null     object
#  3   Actual gross                   20 non-null     int64
#  4   Actual gross(in 2022 dollars)  20 non-null     int64
#  5   Artist                         20 non-null     object
#  6   Tour title                     20 non-null     object
#  7   Year(s)                        20 non-null     object
#  8   Shows                          20 non-null     int64
#  9   Average gross                  20 non-null     int64
#  10  Ref.                           20 non-null     object
# dtypes: int64(5), object(6)
# memory usage: 1.8+ KB

# %%
df.head(8)
# Out:
#    Rank   Peak All Time Peak  Actual gross  Actual gross(in 2022 dollars)  \
# 0     1      1             2     780000000                      780000000
# 1     2      1          7[2]     579800000                      579800000
# 2     3   1[4]          2[5]     411000000                      560622615
# 3     4   2[7]         10[7]     397300000                      454751555
# 4     5   2[4]             0     345675146                      402844849
# 5     6   2[4]         10[9]     305158363                      388978496
# 6     7  2[10]             0     280000000                      381932682
# 7     7      0             0     257600000                      257600000
#
#          Artist                   Tour title    Year(s)  Shows  Average gross  \
# 0  Taylor Swift              The Eras Tour †  2023–2024     56       13928571
# 1       Beyoncé       Renaissance World Tour       2023     56       10353571
# 2       Madonna  Sticky & Sweet Tour ‡[4][a]  2008–2009     85        4835294
# 3          Pink  Beautiful Trauma World Tour  2018–2019    156        2546795
# 4  Taylor Swift      Reputation Stadium Tour       2018     53        6522173
# 5       Madonna                The MDNA Tour       2012     88        3467709
# 6   Celine Dion    Taking Chances World Tour  2008–2009    131        2137405
# 7          Pink            Summer Carnival †  2023–2024     41        6282927
#
#    Ref.
# 0   [1]
# 1   [3]
# 2   [6]
# 3   [7]
# 4   [8]
# 5   [9]
# 6  [11]
# 7  [12]

# %% [markdown]
# get only the numeric values ​​outside the brackets

# %%
df['Peak'] = df['Peak'].str.extract(r'(\d+)')
df['Peak'] = df['Peak'].fillna(0).astype(int)
df['All Time Peak'] = df['All Time Peak'].str.extract(r'(\d+)').fillna(0).astype(int)

# %%
df.head(6)
# Out:
#    Rank  Peak  All Time Peak  Actual gross  Actual gross(in 2022 dollars)  \
# 0     1     1              2     780000000                      780000000
# 1     2     1              7     579800000                      579800000
# 2     3     1              2     411000000                      560622615
# 3     4     2             10     397300000                      454751555
# 4     5     2              0     345675146                      402844849
# 5     6     2             10     305158363                      388978496
#
#          Artist                   Tour title    Year(s)  Shows  Average gross  \
# 0  Taylor Swift              The Eras Tour †  2023–2024     56       13928571
# 1       Beyoncé       Renaissance World Tour       2023     56       10353571
# 2       Madonna  Sticky & Sweet Tour ‡[4][a]  2008–2009     85        4835294
# 3          Pink  Beautiful Trauma World Tour  2018–2019    156        2546795
# 4  Taylor Swift      Reputation Stadium Tour       2018     53        6522173
# 5       Madonna                The MDNA Tour       2012     88        3467709
#
#   Ref.
# 0  [1]
# 1  [3]
# 2  [6]
# 3  [7]
# 4  [8]
# 5  [9]

# %% [markdown]
# remove brackets

# %%
df['Tour title'] = df['Tour title'].str.replace(r'\[.*?\]', '', regex=True)
df.head(6)
# Out:
#    Rank  Peak  All Time Peak  Actual gross  Actual gross(in 2022 dollars)  \
# 0     1     1              2     780000000                      780000000
# 1     2     1              7     579800000                      579800000
# 2     3     1              2     411000000                      560622615
# 3     4     2             10     397300000                      454751555
# 4     5     2              0     345675146                      402844849
# 5     6     2             10     305158363                      388978496
#
#          Artist                   Tour title    Year(s)  Shows  Average gross  \
# 0  Taylor Swift              The Eras Tour †  2023–2024     56       13928571
# 1       Beyoncé       Renaissance World Tour       2023     56       10353571
# 2       Madonna        Sticky & Sweet Tour ‡  2008–2009     85        4835294
# 3          Pink  Beautiful Trauma World Tour  2018–2019    156        2546795
# 4  Taylor Swift      Reputation Stadium Tour       2018     53        6522173
# 5       Madonna                The MDNA Tour       2012     88        3467709
#
#   Ref.
# 0  [1]
# 1  [3]
# 2  [6]
# 3  [7]
# 4  [8]
# 5  [9]

# %% [markdown]
# remove symbols

# %%
df['Tour title'] = df['Tour title'].str.replace(r'[†‡*]', '', regex=True).str.strip()
df.head(6)
# Out:
#    Rank  Peak  All Time Peak  Actual gross  Actual gross(in 2022 dollars)  \
# 0     1     1              2     780000000                      780000000
# 1     2     1              7     579800000                      579800000
# 2     3     1              2     411000000                      560622615
# 3     4     2             10     397300000                      454751555
# 4     5     2              0     345675146                      402844849
# 5     6     2             10     305158363                      388978496
#
#          Artist                   Tour title    Year(s)  Shows  Average gross  \
# 0  Taylor Swift                The Eras Tour  2023–2024     56       13928571
# 1       Beyoncé       Renaissance World Tour       2023     56       10353571
# 2       Madonna          Sticky & Sweet Tour  2008–2009     85        4835294
# 3          Pink  Beautiful Trauma World Tour  2018–2019    156        2546795
# 4  Taylor Swift      Reputation Stadium Tour       2018     53        6522173
# 5       Madonna                The MDNA Tour       2012     88        3467709
#
#   Ref.
# 0  [1]
# 1  [3]
# 2  [6]
# 3  [7]
# 4  [8]
# 5  [9]

# %% [markdown]
# separate the two years and assign them to new columns

# %%
df[['Start Year', 'End Year']] = df['Year(s)'].str.split('–', expand=True)

# %% [markdown]
# convert years from type str to datetime

# %%
df['Start Year'] = pd.to_datetime(df['Start Year'], format='%Y').dt.year
df['End Year'] = df['End Year'].fillna(df['Start Year']).astype('int32')
df.head(6)
# Out:
#    Rank  Peak  All Time Peak  Actual gross  Actual gross(in 2022 dollars)  \
# 0     1     1              2     780000000                      780000000
# 1     2     1              7     579800000                      579800000
# 2     3     1              2     411000000                      560622615
# 3     4     2             10     397300000                      454751555
# 4     5     2              0     345675146                      402844849
# 5     6     2             10     305158363                      388978496
#
#          Artist                   Tour title    Year(s)  Shows  Average gross  \
# 0  Taylor Swift                The Eras Tour  2023–2024     56       13928571
# 1       Beyoncé       Renaissance World Tour       2023     56       10353571
# 2       Madonna          Sticky & Sweet Tour  2008–2009     85        4835294
# 3          Pink  Beautiful Trauma World Tour  2018–2019    156        2546795
# 4  Taylor Swift      Reputation Stadium Tour       2018     53        6522173
# 5       Madonna                The MDNA Tour       2012     88        3467709
#
#   Ref.  Start Year  End Year
# 0  [1]        2023      2024
# 1  [3]        2023      2023
# 2  [6]        2008      2009
# 3  [7]        2018      2019
# 4  [8]        2018      2018
# 5  [9]        2012      2012

# %% [markdown]
# delete unnecessary columns

# %%
df.drop('Year(s)', axis=1, inplace=True)
df.drop('Ref.', axis=1, inplace=True)
df.head(6)
# Out:
#    Rank  Peak  All Time Peak  Actual gross  Actual gross(in 2022 dollars)  \
# 0     1     1              2     780000000                      780000000
# 1     2     1              7     579800000                      579800000
# 2     3     1              2     411000000                      560622615
# 3     4     2             10     397300000                      454751555
# 4     5     2              0     345675146                      402844849
# 5     6     2             10     305158363                      388978496
#
#          Artist                   Tour title  Shows  Average gross  \
# 0  Taylor Swift                The Eras Tour     56       13928571
# 1       Beyoncé       Renaissance World Tour     56       10353571
# 2       Madonna          Sticky & Sweet Tour     85        4835294
# 3          Pink  Beautiful Trauma World Tour    156        2546795
# 4  Taylor Swift      Reputation Stadium Tour     53        6522173
# 5       Madonna                The MDNA Tour     88        3467709
#
#    Start Year  End Year
# 0        2023      2024
# 1        2023      2023
# 2        2008      2009
# 3        2018      2019
# 4        2018      2018
# 5        2012      2012

# %% [markdown]
# ###Results

# %%
df.describe()
df.dtypes
# Out:
# Rank                              int64
# Peak                              int64
# All Time Peak                     int64
# Actual gross                      int64
# Actual gross(in 2022 dollars)     int64
# Artist                           object
# Tour title                       object
# Shows                             int64
# Average gross                     int64
# Start Year                        int32
# End Year                          int32
# dtype: object

# %%
df
# Out:
#     Rank  Peak  All Time Peak  Actual gross  Actual gross(in 2022 dollars)  \
# 0      1     1              2     780000000                      780000000
# 1      2     1              7     579800000                      579800000
# 2      3     1              2     411000000                      560622615
# 3      4     2             10     397300000                      454751555
# 4      5     2              0     345675146                      402844849
# 5      6     2             10     305158363                      388978496
# 6      7     2              0     280000000                      381932682
# 7      7     0              0     257600000                      257600000
# 8      9     0              0     256084556                      312258401
# 9     10     0              0     250400000                      309141878
# 10    11     0              0     229100000                      283202896
# 11    12     0             14     227400000                      295301479
# 12    13     0              0     204000000                      251856802
# 13    14     1              0     200000000                      299676265
# 14    15     2              0     194000000                      281617035
# 15    16     0              0     184000000                      227452347
# 16    17     0              0     170000000                      213568571
# 17    18     0              0     169800000                      207046755
# 18    19     0              0     167700000                      204486106
# 19    20     0              0     150000000                      185423109
#
#           Artist                       Tour title  Shows  Average gross  \
# 0   Taylor Swift                    The Eras Tour     56       13928571
# 1        Beyoncé           Renaissance World Tour     56       10353571
# 2        Madonna              Sticky & Sweet Tour     85        4835294
# 3           Pink      Beautiful Trauma World Tour    156        2546795
# 4   Taylor Swift          Reputation Stadium Tour     53        6522173
# 5        Madonna                    The MDNA Tour     88        3467709
# 6    Celine Dion        Taking Chances World Tour    131        2137405
# 7           Pink                  Summer Carnival     41        6282927
# 8        Beyoncé         The Formation World Tour     49        5226215
# 9   Taylor Swift              The 1989 World Tour     85        2945882
# 10       Beyoncé  The Mrs. Carter Show World Tour    132        1735606
# 11     Lady Gaga            The Monster Ball Tour    203        1118227
# 12    Katy Perry             Prismatic World Tour    151        1350993
# 13          Cher  Living Proof: The Farewell Tour    325         615385
# 14       Madonna                 Confessions Tour     60        3233333
# 15          Pink        The Truth About Love Tour    142        1295775
# 16     Lady Gaga               Born This Way Ball     98        1734694
# 17       Madonna                 Rebel Heart Tour     82        2070732
# 18         Adele                  Adele Live 2016    121        1385950
# 19  Taylor Swift                     The Red Tour     86        1744186
#
#     Start Year  End Year
# 0         2023      2024
# 1         2023      2023
# 2         2008      2009
# 3         2018      2019
# 4         2018      2018
# 5         2012      2012
# 6         2008      2009
# 7         2023      2024
# 8         2016      2016
# 9         2015      2015
# 10        2013      2014
# 11        2009      2011
# 12        2014      2015
# 13        2002      2005
# 14        2006      2006
# 15        2013      2014
# 16        2012      2013
# 17        2015      2016
# 18        2016      2017
# 19        2013      2014

# %% [markdown]
# #Author
# Gabriel Ospina M.
